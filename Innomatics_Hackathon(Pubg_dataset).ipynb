# %% [markdown]
# <a href="https://colab.research.google.com/github/Venu123-sudo/hackathon-/blob/main/Innomatics_Hackathon(Pubg_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Innomatics Hackathon on PUBG dataset

# %% [markdown]
# PUBG  is a popular game which is played by all over world,up to 100 players start in each match (matchId). Players can be on teams (groupId) which get ranked at the end of the game (winPlacePerc) based on how many other teams are still alive when they are eliminated. In game, players can pick up different munitions, revive downed-but-not-out (knocked) teammates, drive vehicles, swim, run, shoot, and experience all of the consequences -- such as falling too far or running themselves over and eliminating themselves.

# %% [markdown]
# #### Importing the Necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Let us load our dataset first and look on the data

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# #### Checking the Head Section of the given dataset

# %%
df.head()
# Out:
#    Unnamed: 0              Id  ... winPoints winPlacePerc
# 0     2093518  a3e3cea9f2e314  ...      1525       0.0667
# 1     3701672  43e4be7ad72cc7  ...      1516       0.5862
# 2     2059784  9a68690e31fdff  ...         0       0.8105
# 3     1302036  b147e1bd448fc4  ...      1515       0.5556
# 4      297180  d818b4edd59612  ...         0       0.6429
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (1111742, 30)

# %% [markdown]
# We can see from the dataset that there are total 11111742 rows and 30 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111742 entries, 0 to 1111741
# Data columns (total 30 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Unnamed: 0       1111742 non-null  int64
#  1   Id               1111742 non-null  object
#  2   groupId          1111742 non-null  object
#  3   matchId          1111742 non-null  object
#  4   assists          1111742 non-null  int64
#  5   boosts           1111742 non-null  int64
#  6   damageDealt      1111742 non-null  float64
#  7   DBNOs            1111742 non-null  int64
#  8   headshotKills    1111742 non-null  int64
#  9   heals            1111742 non-null  int64
#  10  killPlace        1111742 non-null  int64
#  11  killPoints       1111742 non-null  int64
#  12  kills            1111742 non-null  int64
#  13  killStreaks      1111742 non-null  int64
#  14  longestKill      1111742 non-null  float64
#  15  matchDuration    1111742 non-null  int64
# ...

# %% [markdown]
# From the dataset we can see that we total three types of datatypes i.e., float,int,and objects

# %%
#### Checking the Columns in the datasets
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'groupId', 'matchId', 'assists', 'boosts',
#        'damageDealt', 'DBNOs', 'headshotKills', 'heals', 'killPlace',
#        'killPoints', 'kills', 'killStreaks', 'longestKill', 'matchDuration',
#        'matchType', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# #### Let us describe the dataset

# %%
df.describe(include='all').T
# Out:
#                        count   unique  ...          75%          max
# Unnamed: 0       1.11174e+06      NaN  ...  3.33795e+06  4.44696e+06
# Id                   1111742  1111742  ...          NaN          NaN
# groupId              1111742   870622  ...          NaN          NaN
# matchId              1111742    47951  ...          NaN          NaN
# assists          1.11174e+06      NaN  ...            0           17
# boosts           1.11174e+06      NaN  ...            2           24
# damageDealt      1.11174e+06      NaN  ...        185.9         5990
# DBNOs            1.11174e+06      NaN  ...            1           35
# headshotKills    1.11174e+06      NaN  ...            0           64
# heals            1.11174e+06      NaN  ...            2           73
# killPlace        1.11174e+06      NaN  ...           71          100
# killPoints       1.11174e+06      NaN  ...         1171         2170
# kills            1.11174e+06      NaN  ...            1           72
# ...

# %% [markdown]
# By looking to the dataset we can see that there are some NAN values in the dataset

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %% [markdown]
# Now we can see clear data and we dont have any missing values so we can go to visulization part for analysing the data

# %% [markdown]
# #### Now let us check for outliers in our dataset by using the boxplot

# %%
df.plot(kind='box',figsize=(16,16),layout=(8,6),sharex=False,subplots=True)
# Out:
# Unnamed: 0            AxesSubplot(0.125,0.799681;0.110714x0.0803191)
# assists            AxesSubplot(0.257857,0.799681;0.110714x0.0803191)
# boosts             AxesSubplot(0.390714,0.799681;0.110714x0.0803191)
# damageDealt        AxesSubplot(0.523571,0.799681;0.110714x0.0803191)
# DBNOs              AxesSubplot(0.656429,0.799681;0.110714x0.0803191)
# headshotKills      AxesSubplot(0.789286,0.799681;0.110714x0.0803191)
# heals                 AxesSubplot(0.125,0.703298;0.110714x0.0803191)
# killPlace          AxesSubplot(0.257857,0.703298;0.110714x0.0803191)
# killPoints         AxesSubplot(0.390714,0.703298;0.110714x0.0803191)
# kills              AxesSubplot(0.523571,0.703298;0.110714x0.0803191)
# killStreaks        AxesSubplot(0.656429,0.703298;0.110714x0.0803191)
# longestKill        AxesSubplot(0.789286,0.703298;0.110714x0.0803191)
# matchDuration         AxesSubplot(0.125,0.606915;0.110714x0.0803191)
# maxPlace           AxesSubplot(0.257857,0.606915;0.110714x0.0803191)
# ...

# %% [markdown]
# We can see from the Data that there is alot of outliers in the each feature lets remove this outliers by using the IQR technique

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

final_df=cap_data(df)
# Out:
# capping the  Unnamed: 0
# capping the  Id
# capping the  groupId
# capping the  matchId
# capping the  assists
# capping the  boosts
# capping the  damageDealt
# capping the  DBNOs
# capping the  headshotKills
# capping the  heals
# capping the  killPlace
# capping the  killPoints
# capping the  kills
# capping the  killStreaks
# capping the  longestKill
# capping the  matchDuration
# capping the  matchType
# capping the  maxPlace
# capping the  numGroups
# capping the  rankPoints
# capping the  revives
# capping the  rideDistance
# capping the  roadKills
# capping the  swimDistance
# capping the  teamKills
# capping the  vehicleDestroys
# capping the  walkDistance
# capping the  weaponsAcquired
# capping the  winPoints
# capping the  winPlacePerc

# %%
df.plot(kind='box',figsize=(16,16),layout=(8,6),sharex=False,subplots=True)
# Out:
# Unnamed: 0            AxesSubplot(0.125,0.799681;0.110714x0.0803191)
# assists            AxesSubplot(0.257857,0.799681;0.110714x0.0803191)
# boosts             AxesSubplot(0.390714,0.799681;0.110714x0.0803191)
# damageDealt        AxesSubplot(0.523571,0.799681;0.110714x0.0803191)
# DBNOs              AxesSubplot(0.656429,0.799681;0.110714x0.0803191)
# headshotKills      AxesSubplot(0.789286,0.799681;0.110714x0.0803191)
# heals                 AxesSubplot(0.125,0.703298;0.110714x0.0803191)
# killPlace          AxesSubplot(0.257857,0.703298;0.110714x0.0803191)
# killPoints         AxesSubplot(0.390714,0.703298;0.110714x0.0803191)
# kills              AxesSubplot(0.523571,0.703298;0.110714x0.0803191)
# killStreaks        AxesSubplot(0.656429,0.703298;0.110714x0.0803191)
# longestKill        AxesSubplot(0.789286,0.703298;0.110714x0.0803191)
# matchDuration         AxesSubplot(0.125,0.606915;0.110714x0.0803191)
# maxPlace           AxesSubplot(0.257857,0.606915;0.110714x0.0803191)
# ...

# %%
plt.boxplot(df['swimDistance'])
plt.title('Boxplot before removing the outliers')
plt.show()

def drop_outliers(df, field_name):
    iqr = 1.5 *(np.percentile(df[field_name],75) - np.percentile(df[field_name],25))
    df.drop(df[df[field_name]>(iqr+ np.percentile(df[field_name],75))].index,inplace=True)
    df.drop(df[df[field_name]<(np.percentile(df[field_name],25)-iqr)].index,inplace=True)

drop_outliers(df, 'swimDistance')
plt.boxplot(df['swimDistance'])
plt.title('Box plot after removing outliers')
plt.show()

# %%
plt.boxplot(df['rideDistance'])
plt.title('Boxplot before removing the outliers')
plt.show()

def drop_outliers(df, field_name):
    iqr = 1.5 *(np.percentile(df[field_name],75) - np.percentile(df[field_name],25))
    df.drop(df[df[field_name]>(iqr+ np.percentile(df[field_name],75))].index,inplace=True)
    df.drop(df[df[field_name]<(np.percentile(df[field_name],25)-iqr)].index,inplace=True)

drop_outliers(df, 'rideDistance')
plt.boxplot(df['rideDistance'])
plt.title('Box plot after removing outliers')
plt.show()

# %%
plt.boxplot(df['longestKill'])
plt.title('Boxplot before removing the outliers')
plt.show()

def drop_outliers(df, field_name):
    iqr = 1.5 *(np.percentile(df[field_name],75) - np.percentile(df[field_name],25))
    df.drop(df[df[field_name]>(iqr+ np.percentile(df[field_name],75))].index,inplace=True)
    df.drop(df[df[field_name]<(np.percentile(df[field_name],25)-iqr)].index,inplace=True)

drop_outliers(df, 'longestKill')
plt.boxplot(df['longestKill'])
plt.title('Box plot after removing outliers')
plt.show()

# %%
df.plot(kind='box',figsize=(16,16),layout=(8,6),sharex=False,subplots=True)
# Out:
# Unnamed: 0            AxesSubplot(0.125,0.799681;0.110714x0.0803191)
# assists            AxesSubplot(0.257857,0.799681;0.110714x0.0803191)
# boosts             AxesSubplot(0.390714,0.799681;0.110714x0.0803191)
# damageDealt        AxesSubplot(0.523571,0.799681;0.110714x0.0803191)
# DBNOs              AxesSubplot(0.656429,0.799681;0.110714x0.0803191)
# headshotKills      AxesSubplot(0.789286,0.799681;0.110714x0.0803191)
# heals                 AxesSubplot(0.125,0.703298;0.110714x0.0803191)
# killPlace          AxesSubplot(0.257857,0.703298;0.110714x0.0803191)
# killPoints         AxesSubplot(0.390714,0.703298;0.110714x0.0803191)
# kills              AxesSubplot(0.523571,0.703298;0.110714x0.0803191)
# killStreaks        AxesSubplot(0.656429,0.703298;0.110714x0.0803191)
# longestKill        AxesSubplot(0.789286,0.703298;0.110714x0.0803191)
# matchDuration         AxesSubplot(0.125,0.606915;0.110714x0.0803191)
# maxPlace           AxesSubplot(0.257857,0.606915;0.110714x0.0803191)
# ...

# %% [markdown]
# Compare to previous data outliers we have cleared the maximum amount of outliers by using the IQR techique and now we can move to EDA part for exploring more about the data

# %% [markdown]
# #### Now let's check the total kills of an individual and his percentage of kills by using the following method

# %%
print("The average person kills {:.4f} players, 99% of people have {} kills or less, while the most kills ever recorded is {}.".format(df['kills'].mean(),df['kills'].quantile(0.99), df['kills'].max()))
# Out:
# The average person kills 0.0031 players, 99% of people have 0.0 kills or less, while the most kills ever recorded is 7.

# %% [markdown]
# #### Let us check the kill count of each individual or group of members  by using the countplot

# %%
data = df.copy()
data.loc[data['kills'] > data['kills'].quantile(0.99)] = '8+'
plt.figure(figsize=(15,10))
sns.countplot(data['kills'].astype('str').sort_values())
plt.title("Kill Count",fontsize=15)
plt.show()

# %% [markdown]
# The most of the kill count are for each individual or a group with 1 - 3 players is of 48000

# %% [markdown]
# #### Most people atleast can't make a single kill, atleast they do make damage so let us check the damagedelt column to look into it

# %%
data = df.copy()
data = data[data['kills']==0]
plt.figure(figsize=(15,10))
plt.title("Damage Dealt by 0 killers",fontsize=15)
sns.distplot(data['damageDealt'])
plt.show()

# %% [markdown]
# From the above graph we can see that there is less damagedealt when compare to atleast a single kill by individual so lets analyze more to get insights from data

# %%
print("{} players ({:.4f}%) have won without a single kill!".format(len(data[data['winPlacePerc']==1]), 100*len(data[data['winPlacePerc']==1])/len(df)))

data1 = df[df['damageDealt'] == 0].copy()
print("{} players ({:.4f}%) have won without dealing damage!".format(len(data1[data1['winPlacePerc']==1]), 100*len(data1[data1['winPlacePerc']==1])/len(df)))
# Out:
# 1968 players (0.4040%) have won without a single kill!
# 622 players (0.1277%) have won without dealing damage!

# %% [markdown]
# From the above results we can see that 1968 players has a 40% have won without having a single kill wow thats amazing 😎 and 622 players has 12% have won without dealing the damage

# %% [markdown]
# #### Let us check the win placment percentage and kills columns by using the scatter plot

# %%
sns.jointplot(x="winPlacePerc", y="kills", data=df, height=10, ratio=3, color="g")
plt.show()

# %% [markdown]
# Apparentrly killing has a correlation with winning. So finally let's group players based on kills i.e., (0 kills, 1-2 kills, 3-5 kills, 6-10 kills and 10+ kills).

# %%
### Let us perform boxplot to check the relation b/w no of kills to the win percentage

kills = df.copy()

kills['killsCategories'] = pd.cut(kills['kills'], [-1, 0, 2, 5, 10, 60], labels=['0_kills','1-2_kills', '3-5_kills', '6-10_kills', '10+_kills'])

plt.figure(figsize=(15,8))
sns.boxplot(x="killsCategories", y="winPlacePerc", data=kills)
plt.show()

# %% [markdown]
# From the above boxplot we can say that a person who has kills(1-2) has a highest win percentage of about 48%

# %% [markdown]
# #### Let us check the No of persons Walking on the battleground on an average throughout the complete game

# %%
print("The average person walks for {:.1f}m, 99% of people have walked {}m or less, while the marathoner champion walked for {}m.".format(df['walkDistance'].mean(), df['walkDistance'].quantile(0.99), df['walkDistance'].max()))
# Out:
# The average person walks for 538.3m, 99% of people have walked 3424.0m or less, while the marathoner champion walked for 4393.0m.

# %% [markdown]
# We can see from above output on an average a person walks 538.5m, and 99% of people have walked 3424.0m 🙄 or less where a marathoner champion walks nearly 4393.0m

# %% [markdown]
# #### Let us check the walk Distance column by using the Distribution plot

# %%
data = df.copy()
data = data[data['walkDistance'] < df['walkDistance'].quantile(0.99)]
plt.figure(figsize=(15,10))
plt.title("Walking Distance Distribution",fontsize=15)
sns.distplot(data['walkDistance'])
plt.show()

# %% [markdown]
# From the distribution plot we can see that average persons walking on battleground is of 500m

# %% [markdown]
# #### Let us check how many are died before having a single step in the arena

# %%
print("{} players ({:.4f}%) walked 0 meters. This means that they die before even taking a step or they are afk (more possible).".format(len(data[data['walkDistance'] == 0]), 100*len(data1[data1['walkDistance']==0])/len(df)))
# Out:
# 24025 players (4.5521%) walked 0 meters. This means that they die before even taking a step or they are afk (more possible).

# %% [markdown]
# We can clearly see that there are nearly 4.5% people die before they are taking a single step on the ground

# %%
sns.jointplot(x="winPlacePerc", y="walkDistance",  data=df, height=10, ratio=3, color="lime")
plt.show()

# %% [markdown]
# Apprently walking has high correlation with the win peercentage

# %% [markdown]
# #### Let us check the ride percentage of each person by doing following method

# %%
print("The average person drives for {:.1f}m, 99% of people have drived {}m or less, while the formula 1 champion drived for {}m.".format(df['rideDistance'].mean(), df['rideDistance'].quantile(0.99), df['rideDistance'].max()))
# Out:
# The average person drives for 0.0m, 99% of people have drived 0.0m or less, while the formula 1 champion drived for 0.0m.

# %% [markdown]
# From the above result we can say that 99% of people have drived 0m or less.

# %% [markdown]
# #### Let us check a person has driving licence or not based on his riding data

# %%
print("{} players ({:.4f}%) drived for 0 meters. This means that they do have a driving licence.".format(len(data[data['rideDistance'] == 0]), 100*len(data1[data1['rideDistance']==0])/len(df)))
# Out:
# 482199 players (50.9381%) drived for 0 meters. This means that they do have a driving licence.

# %% [markdown]
# From the above result we can say that some people has ride without using the licence it means 50% of people drived without having the driving licence

# %%
### ploting the graph to check the relationship b/w win percentage and ride distance using the Joinplot
sns.jointplot(x="winPlacePerc", y="rideDistance", data=df, height=10, ratio=3, color="r")
plt.show()

# %% [markdown]
# by looking above plot we can that there is high correlation b/w ride Distance and win percentage

# %% [markdown]
# #### As per my knowledge destroying the vechile shows that the person has good skills in the game. so let us check it once

# %%
### Using the pointplot to show the relation b/w the vechile destory and win place percent
f,ax1 = plt.subplots(figsize =(20,10))
sns.pointplot(x='vehicleDestroys',y='winPlacePerc',data=data,color='#606060',alpha=0.8)
plt.xlabel('Number of Vehicle Destroys',fontsize = 15,color='blue')
plt.ylabel('Vehicle destroys/win ratio',fontsize = 15,color='blue')
plt.title('Win percentage',fontsize = 20,color='blue')
plt.grid()
plt.show()

# %% [markdown]
# here from the data we can see that we dont much vehicle damages if there is vehicle damages and my assumation would be correct i.e., destroying a vehicle gives us winning chances

# %% [markdown]
# #### Let us look on the Healing prospective where how many have used doctor for help or they got healed by themself

# %%
print("The average person uses {:.1f} heal items, 99% of people use {} or less, while the doctor used {}.".format(df['heals'].mean(), df['heals'].quantile(0.99), df['heals'].max()))
print("The average person uses {:.1f} boost items, 99% of people use {} or less, while the doctor used {}.".format(df['boosts'].mean(), df['boosts'].quantile(0.99), df['boosts'].max()))
# Out:
# The average person uses 0.4 heal items, 99% of people use 7.0 or less, while the doctor used 12.
# The average person uses 0.3 boost items, 99% of people use 4.0 or less, while the doctor used 7.

# %%
data = df.copy()
data = data[data['heals'] < data['heals'].quantile(0.99)]
data = data[data['boosts'] < data['boosts'].quantile(0.99)]

f,ax1 = plt.subplots(figsize =(20,10))
sns.pointplot(x='heals',y='winPlacePerc',data=data,color='lime',alpha=0.8)
sns.pointplot(x='boosts',y='winPlacePerc',data=data,color='blue',alpha=0.8)
plt.text(4,0.6,'Heals',color='lime',fontsize = 17,style = 'italic')
plt.text(4,0.55,'Boosts',color='blue',fontsize = 17,style = 'italic')
plt.xlabel('Number of heal/boost items',fontsize = 15,color='blue')
plt.ylabel('Win Percentage',fontsize = 15,color='blue')
plt.title('Heals vs Boosts',fontsize = 20,color='blue')
plt.grid()
plt.show()

# %%
## let us check the realtionship b/w the win percentage and heals 
sns.jointplot(x="winPlacePerc", y="heals", data=df, height=10, ratio=3, color="lime")
plt.show()

# %%
sns.jointplot(x="winPlacePerc", y="boosts", data=df, height=10, ratio=3, color="blue")
plt.show()

# %% [markdown]
# So healing and boosting, definately are correlated with winPlacePerc. Boosting is more. so we can say that when percentage is defineatly depend on boosting and healing column

# %% [markdown]
# ### Solos, Duos and Squads
#
# There are 3 game modes in the game. One can play solo, or with a friend (duo), or with 3 other friends (squad). 100 players join the same server, so in the case of duos the max teams are 50 and in the case of squads the max teams are 25.

# %%
solos = df[df['numGroups']>35]
duos = df[(df['numGroups']>25) & (df['numGroups']<=35)]
squads = df[df['numGroups']<=25]
print("There are {} ({:.2f}%) solo games, {} ({:.2f}%) duo games and {} ({:.2f}%) squad games.".format(len(solos), 100*len(solos)/len(df), len(duos), 100*len(duos)/len(df), len(squads), 100*len(squads)/len(df),))
# Out:
# There are 227294 (46.67%) solo games, 213332 (43.80%) duo games and 46448 (9.54%) squad games.

# %% [markdown]
# From the above result we can say that there 16% who play solo games and 73% who play duo games and 9% who play the sqaud games

# %%
f,ax1 = plt.subplots(figsize =(12,6))
sns.pointplot(x='kills',y='winPlacePerc',data=solos,color='black',alpha=0.8)
sns.pointplot(x='kills',y='winPlacePerc',data=duos,color='#CC0000',alpha=0.8)
sns.pointplot(x='kills',y='winPlacePerc',data=squads,color='#3399FF',alpha=0.8)
plt.text(37,0.6,'Solos',color='black',fontsize = 17,style = 'italic')
plt.text(37,0.55,'Duos',color='#CC0000',fontsize = 17,style = 'italic')
plt.text(37,0.5,'Squads',color='#3399FF',fontsize = 17,style = 'italic')
plt.xlabel('Number of kills',fontsize = 15,color='blue')
plt.ylabel('Win Percentage',fontsize = 15,color='blue')
plt.title('Solo vs Duo vs Squad Kills',fontsize = 20,color='blue')
plt.grid()
plt.show()

# %% [markdown]
# Hmm, very interesting. Solos and duos behave the same, but when playing squads kills don't matter that much.

# %% [markdown]
# The attribute DBNOs means enemy players knocked. A "knock" can happen only in duos or squads, because the teammates have the chance to "revive" the knocked player in a given time. So a knocked player can be revived or die. If he is revived, the next time he will be knocked, his teammates will have less time to revive him.
#
# The attribute assist can also happen only in duos or squads. It generally means that the player had an involvement in a kill.
#
# The attribute revive also happens in duos or squads.

# %% [markdown]
# #### Checking the Pearson corelation between the variables

# %%
k = 5 #number of variables for heatmap
f,ax = plt.subplots(figsize=(11, 11))
cols = df.corr().nlargest(k, 'winPlacePerc')['winPlacePerc'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Let's plot the above choosed variables and the killPlace variable as pairs

# %%
sns.set()
cols = ['winPlacePerc', 'walkDistance', 'boosts', 'weaponsAcquired', 'damageDealt', 'killPlace']
sns.pairplot(train[cols], size = 2.5)
plt.show()

# %%
sns.jointplot(x='killPlace',y='winPlacePerc',data=df,kind='hex')
